# %%
# Function to rename and move folders
def rename_and_merge(source_path, destination_path):
    for plant in os.listdir(source_path):  # Loop through plants (e.g., Apple, Bell Pepper)
        plant_path = os.path.join(source_path, plant)
        if os.path.isdir(plant_path):
            for split in ['Train', 'Val', 'Test']:
                split_path = os.path.join(plant_path, split)
                if os.path.isdir(split_path):
                    for condition in os.listdir(split_path):  # E.g., Healthy, Apple Scab
                        condition_path = os.path.join(split_path, condition)
                        if os.path.isdir(condition_path) and not condition.startswith('.'):  # Ignore hidden dirs
                            # Create a new folder name with plant name
                            if condition.lower() == "healthy":
                                new_folder_name = f"{plant}_Healthy"
                            else:
                                new_folder_name = f"{plant}_{condition.replace(' ', '_')}"
                            
                            # Create destination folder
                            target_folder = os.path.join(destination_path, split, new_folder_name)
                            os.makedirs(target_folder, exist_ok=True)
                            
                            # Move all images to the renamed folder
                            for img in os.listdir(condition_path):
                                src = os.path.join(condition_path, img)
                                dest = os.path.join(target_folder, img)
                                if os.path.isfile(src):  # Ensure src is a file
                                    shutil.copy(src, dest)

# Rename and merge
rename_and_merge(source_path, destination_path)
print("Dataset reorganized and renamed successfully!")
# Out:
# Dataset reorganized and renamed successfully!

# %%
from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import DataLoader

# Paths for the renamed dataset
TRAIN_PATH = '/kaggle/working/renamed_dataset/Train'
VAL_PATH = '/kaggle/working/renamed_dataset/Val'
TEST_PATH = '/kaggle/working/renamed_dataset/Test'

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load datasets
train_dataset = ImageFolder(TRAIN_PATH, transform=transform)
val_dataset = ImageFolder(VAL_PATH, transform=transform)
test_dataset = ImageFolder(TEST_PATH, transform=transform)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Print class names
print(f"Classes: {train_dataset.classes}")
print(f"Number of classes: {len(train_dataset.classes)}")
print(f"Training samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")
# Out:
# Classes: ['Apple_Apple_Scab', 'Apple_Black_Rot', 'Apple_Cedar_Apple_Rust', 'Apple_Healthy', 'Bell Pepper_Bacterial_Spot', 'Bell Pepper_Healthy', 'Cherry_Healthy', 'Cherry_Powdery_Mildew', 'Corn (Maize)_Cercospora_Leaf_Spot', 'Corn (Maize)_Common_Rust_', 'Corn (Maize)_Healthy', 'Corn (Maize)_Northern_Leaf_Blight', 'Grape_Black_Rot', 'Grape_Esca_(Black_Measles)', 'Grape_Healthy', 'Grape_Leaf_Blight', 'Peach_Bacterial_Spot', 'Peach_Healthy', 'Potato_Early_Blight', 'Potato_Healthy', 'Potato_Late_Blight', 'Strawberry_Healthy', 'Strawberry_Leaf_Scorch', 'Tomato_Bacterial_Spot', 'Tomato_Early_Blight', 'Tomato_Healthy', 'Tomato_Late_Blight', 'Tomato_Septoria_Leaf_Spot', 'Tomato_Yellow_Leaf_Curl_Virus']
# Number of classes: 29
# Training samples: 53690
# Validation samples: 12067
# Test samples: 1354

# %%
import timm
import torch
from torch import nn

# Load the PiT model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = timm.create_model('pit_s_224', pretrained=True, num_classes=len(train_dataset.classes))
model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)

print("Model loaded successfully!")
# Out:
# model.safetensors:   0%|          | 0.00/93.9M [00:00<?, ?B/s]
# Model loaded successfully!

# %%
def train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs=10):
    for epoch in range(epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, preds = outputs.max(1)
            correct += preds.eq(labels).sum().item()
            total += labels.size(0)

        train_accuracy = 100 * correct / total
        print(f"Epoch {epoch+1}: Train Loss = {running_loss:.4f}, Train Accuracy = {train_accuracy:.2f}%")

        # Validation phase
        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, preds = outputs.max(1)
                correct += preds.eq(labels).sum().item()
                total += labels.size(0)

        val_accuracy = 100 * correct / total
        print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")

# Train the model
train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs=10)
# Out:
# Epoch 1: Train Loss = 171.5080, Train Accuracy = 96.57%
# Validation Loss: 39.1473, Validation Accuracy: 96.54%
# Epoch 2: Train Loss = 154.6822, Train Accuracy = 96.98%
# Validation Loss: 79.2957, Validation Accuracy: 93.26%
# Epoch 3: Train Loss = 129.2795, Train Accuracy = 97.41%
# Validation Loss: 32.2419, Validation Accuracy: 97.06%
# Epoch 4: Train Loss = 121.4094, Train Accuracy = 97.52%
# Validation Loss: 25.8061, Validation Accuracy: 97.80%
# Epoch 5: Train Loss = 112.3741, Train Accuracy = 97.71%
# Validation Loss: 34.2649, Validation Accuracy: 97.11%
# Epoch 6: Train Loss = 109.8763, Train Accuracy = 97.76%
# Validation Loss: 37.2013, Validation Accuracy: 96.64%
# Epoch 7: Train Loss = 93.6765, Train Accuracy = 98.12%
# Validation Loss: 21.4213, Validation Accuracy: 98.06%
# Epoch 8: Train Loss = 92.4043, Train Accuracy = 98.11%
# Validation Loss: 28.5459, Validation Accuracy: 97.42%
# Epoch 9: Train Loss = 87.2006, Train Accuracy = 98.22%
# Validation Loss: 26.2749, Validation Accuracy: 97.75%
# Epoch 10: Train Loss = 77.5069, Train Accuracy = 98.43%
# Validation Loss: 25.0484, Validation Accuracy: 97.51%

# %%
torch.save(model.state_dict(), '/kaggle/working/pit_model_final.pth')
print("Model saved at /kaggle/working/pit_model_final.pth")
# Out:
# Model saved at /kaggle/working/pit_model_final.pth

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

def evaluate_model(model, test_loader):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = outputs.max(1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Generate classification report
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=test_dataset.classes))

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=test_dataset.classes, yticklabels=test_dataset.classes, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Evaluate the model
evaluate_model(model, test_loader)
# Out:
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                  Apple_Apple_Scab       1.00      0.94      0.97        51
#                   Apple_Black_Rot       1.00      0.98      0.99        50
#            Apple_Cedar_Apple_Rust       1.00      0.98      0.99        44
#                     Apple_Healthy       0.96      1.00      0.98        51
#        Bell Pepper_Bacterial_Spot       1.00      1.00      1.00        48
#               Bell Pepper_Healthy       0.98      0.96      0.97        50
#                    Cherry_Healthy       0.98      1.00      0.99        46
#             Cherry_Powdery_Mildew       1.00      1.00      1.00        43
# Corn (Maize)_Cercospora_Leaf_Spot       0.95      0.95      0.95        41
#         Corn (Maize)_Common_Rust_       1.00      0.98      0.99        48
#              Corn (Maize)_Healthy       0.98      1.00      0.99        47
# Corn (Maize)_Northern_Leaf_Blight       0.96      0.96      0.96        48
#                   Grape_Black_Rot       0.98      1.00      0.99        48
#        Grape_Esca_(Black_Measles)       1.00      1.00      1.00        48
#                     Grape_Healthy       1.00      1.00      1.00        43
#                 Grape_Leaf_Blight       1.00      0.95      0.98        43
#              Peach_Bacterial_Spot       0.98      1.00      0.99        46
#                     Peach_Healthy       1.00      0.98      0.99        44
#               Potato_Early_Blight       0.94      1.00      0.97        49
#                    Potato_Healthy       0.96      0.98      0.97        46
#                Potato_Late_Blight       1.00      1.00      1.00        49
#                Strawberry_Healthy       0.96      0.98      0.97        46
#            Strawberry_Leaf_Scorch       1.00      1.00      1.00        45
#             Tomato_Bacterial_Spot       1.00      0.91      0.95        43
#               Tomato_Early_Blight       0.92      0.98      0.95        48
#                    Tomato_Healthy       0.96      1.00      0.98        49
#                Tomato_Late_Blight       1.00      0.98      0.99        47
#         Tomato_Septoria_Leaf_Spot       1.00      0.93      0.96        44
#     Tomato_Yellow_Leaf_Curl_Virus       0.96      1.00      0.98        49
#
#                          accuracy                           0.98      1354
#                         macro avg       0.98      0.98      0.98      1354
#                      weighted avg       0.98      0.98      0.98      1354

# %%
# !pip install ptflops
# Out:
# Collecting ptflops
#   Downloading ptflops-0.7.4-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch>=2.0 in /opt/conda/lib/python3.10/site-packages (from ptflops) (2.4.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.0->ptflops) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.0->ptflops) (1.3.0)
# Downloading ptflops-0.7.4-py3-none-any.whl (19 kB)
# Installing collected packages: ptflops
# Successfully installed ptflops-0.7.4

# %%
from ptflops import get_model_complexity_info

# Input size for the PiT model (C=3, H=W=224 for ImageNet-sized images)
input_size = (3, 224, 224)

# Calculate FLOPs and parameters
with torch.no_grad():
    macs, params = get_model_complexity_info(model, input_size, as_strings=True, verbose=True)
    print(f"FLOPs: {macs}")
    print(f"Number of parameters: {params}")
# Out:
# Warning: module ConvEmbedding is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module Identity is treated as a zero-op.
# Warning: module Mlp is treated as a zero-op.
# Warning: module Block is treated as a zero-op.
# Warning: module Transformer is treated as a zero-op.
# Warning: module Pooling is treated as a zero-op.
# Warning: module SequentialTuple is treated as a zero-op.
# Warning: module PoolingVisionTransformer is treated as a zero-op.
# PoolingVisionTransformer(
#   22.8 M, 99.541% Params, 2.1 GMac, 99.874% MACs,
#   (patch_embed): ConvEmbedding(
#     110.74 k, 0.484% Params, 80.73 MMac, 3.831% MACs,
#     (conv): Conv2d(110.74 k, 0.484% Params, 80.73 MMac, 3.831% MACs, 3, 144, kernel_size=(16, 16), stride=(8, 8))
#   )
#   (pos_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#   (transformers): SequentialTuple(
#     22.67 M, 98.979% Params, 2.02 GMac, 96.042% MACs,
#     (0): Transformer(
#       501.41 k, 2.189% Params, 554.87 MMac, 26.333% MACs,
#       (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (blocks): Sequential(
#         501.41 k, 2.189% Params, 554.87 MMac, 26.333% MACs,
#         (0): Block(
#           250.7 k, 1.095% Params, 277.43 MMac, 13.166% MACs,
#           (norm1): LayerNorm(288, 0.001% Params, 105.12 KMac, 0.005% MACs, (144,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             83.52 k, 0.365% Params, 155.18 MMac, 7.365% MACs,
#             (qkv): Linear(62.64 k, 0.274% Params, 45.73 MMac, 2.170% MACs, in_features=144, out_features=432, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(20.88 k, 0.091% Params, 15.24 MMac, 0.723% MACs, in_features=144, out_features=144, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(288, 0.001% Params, 105.12 KMac, 0.005% MACs, (144,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             166.61 k, 0.727% Params, 122.04 MMac, 5.792% MACs,
#             (fc1): Linear(83.52 k, 0.365% Params, 60.97 MMac, 2.894% MACs, in_features=144, out_features=576, bias=True)
#             (act): GELU(0, 0.000% Params, 420.48 KMac, 0.020% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(83.09 k, 0.363% Params, 60.65 MMac, 2.879% MACs, in_features=576, out_features=144, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (1): Block(
#           250.7 k, 1.095% Params, 277.43 MMac, 13.166% MACs,
#           (norm1): LayerNorm(288, 0.001% Params, 105.12 KMac, 0.005% MACs, (144,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             83.52 k, 0.365% Params, 155.18 MMac, 7.365% MACs,
#             (qkv): Linear(62.64 k, 0.274% Params, 45.73 MMac, 2.170% MACs, in_features=144, out_features=432, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(20.88 k, 0.091% Params, 15.24 MMac, 0.723% MACs, in_features=144, out_features=144, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(288, 0.001% Params, 105.12 KMac, 0.005% MACs, (144,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             166.61 k, 0.727% Params, 122.04 MMac, 5.792% MACs,
#             (fc1): Linear(83.52 k, 0.365% Params, 60.97 MMac, 2.894% MACs, in_features=144, out_features=576, bias=True)
#             (act): GELU(0, 0.000% Params, 420.48 KMac, 0.020% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(83.09 k, 0.363% Params, 60.65 MMac, 2.879% MACs, in_features=576, out_features=144, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#     )
#     (1): Transformer(
#       6.04 M, 26.370% Params, 924.53 MMac, 43.877% MACs,
#       (pool): Pooling(
#         44.64 k, 0.195% Params, 606.24 KMac, 0.029% MACs,
#         (conv): Conv2d(2.88 k, 0.013% Params, 564.48 KMac, 0.027% MACs, 144, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144)
#         (fc): Linear(41.76 k, 0.182% Params, 41.76 KMac, 0.002% MACs, in_features=144, out_features=288, bias=True)
#       )
#       (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (blocks): Sequential(
#         5.99 M, 26.175% Params, 923.92 MMac, 43.848% MACs,
#         (0): Block(
#           999.07 k, 4.362% Params, 153.99 MMac, 7.308% MACs,
#           (norm1): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             332.93 k, 1.454% Params, 22.64 MMac, 1.075% MACs,
#             (qkv): Linear(249.7 k, 1.090% Params, 49.19 MMac, 2.334% MACs, in_features=288, out_features=864, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(83.23 k, 0.363% Params, 16.4 MMac, 0.778% MACs, in_features=288, out_features=288, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             664.99 k, 2.904% Params, 131.23 MMac, 6.228% MACs,
#             (fc1): Linear(332.93 k, 1.454% Params, 65.59 MMac, 3.113% MACs, in_features=288, out_features=1152, bias=True)
#             (act): GELU(0, 0.000% Params, 226.94 KMac, 0.011% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(332.06 k, 1.450% Params, 65.42 MMac, 3.105% MACs, in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (1): Block(
#           999.07 k, 4.362% Params, 153.99 MMac, 7.308% MACs,
#           (norm1): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             332.93 k, 1.454% Params, 22.64 MMac, 1.075% MACs,
#             (qkv): Linear(249.7 k, 1.090% Params, 49.19 MMac, 2.334% MACs, in_features=288, out_features=864, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(83.23 k, 0.363% Params, 16.4 MMac, 0.778% MACs, in_features=288, out_features=288, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             664.99 k, 2.904% Params, 131.23 MMac, 6.228% MACs,
#             (fc1): Linear(332.93 k, 1.454% Params, 65.59 MMac, 3.113% MACs, in_features=288, out_features=1152, bias=True)
#             (act): GELU(0, 0.000% Params, 226.94 KMac, 0.011% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(332.06 k, 1.450% Params, 65.42 MMac, 3.105% MACs, in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (2): Block(
#           999.07 k, 4.362% Params, 153.99 MMac, 7.308% MACs,
#           (norm1): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             332.93 k, 1.454% Params, 22.64 MMac, 1.075% MACs,
#             (qkv): Linear(249.7 k, 1.090% Params, 49.19 MMac, 2.334% MACs, in_features=288, out_features=864, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(83.23 k, 0.363% Params, 16.4 MMac, 0.778% MACs, in_features=288, out_features=288, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             664.99 k, 2.904% Params, 131.23 MMac, 6.228% MACs,
#             (fc1): Linear(332.93 k, 1.454% Params, 65.59 MMac, 3.113% MACs, in_features=288, out_features=1152, bias=True)
#             (act): GELU(0, 0.000% Params, 226.94 KMac, 0.011% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(332.06 k, 1.450% Params, 65.42 MMac, 3.105% MACs, in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (3): Block(
#           999.07 k, 4.362% Params, 153.99 MMac, 7.308% MACs,
#           (norm1): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             332.93 k, 1.454% Params, 22.64 MMac, 1.075% MACs,
#             (qkv): Linear(249.7 k, 1.090% Params, 49.19 MMac, 2.334% MACs, in_features=288, out_features=864, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(83.23 k, 0.363% Params, 16.4 MMac, 0.778% MACs, in_features=288, out_features=288, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             664.99 k, 2.904% Params, 131.23 MMac, 6.228% MACs,
#             (fc1): Linear(332.93 k, 1.454% Params, 65.59 MMac, 3.113% MACs, in_features=288, out_features=1152, bias=True)
#             (act): GELU(0, 0.000% Params, 226.94 KMac, 0.011% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(332.06 k, 1.450% Params, 65.42 MMac, 3.105% MACs, in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (4): Block(
#           999.07 k, 4.362% Params, 153.99 MMac, 7.308% MACs,
#           (norm1): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             332.93 k, 1.454% Params, 22.64 MMac, 1.075% MACs,
#             (qkv): Linear(249.7 k, 1.090% Params, 49.19 MMac, 2.334% MACs, in_features=288, out_features=864, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(83.23 k, 0.363% Params, 16.4 MMac, 0.778% MACs, in_features=288, out_features=288, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             664.99 k, 2.904% Params, 131.23 MMac, 6.228% MACs,
#             (fc1): Linear(332.93 k, 1.454% Params, 65.59 MMac, 3.113% MACs, in_features=288, out_features=1152, bias=True)
#             (act): GELU(0, 0.000% Params, 226.94 KMac, 0.011% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(332.06 k, 1.450% Params, 65.42 MMac, 3.105% MACs, in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (5): Block(
#           999.07 k, 4.362% Params, 153.99 MMac, 7.308% MACs,
#           (norm1): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             332.93 k, 1.454% Params, 22.64 MMac, 1.075% MACs,
#             (qkv): Linear(249.7 k, 1.090% Params, 49.19 MMac, 2.334% MACs, in_features=288, out_features=864, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(83.23 k, 0.363% Params, 16.4 MMac, 0.778% MACs, in_features=288, out_features=288, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(576, 0.003% Params, 56.74 KMac, 0.003% MACs, (288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             664.99 k, 2.904% Params, 131.23 MMac, 6.228% MACs,
#             (fc1): Linear(332.93 k, 1.454% Params, 65.59 MMac, 3.113% MACs, in_features=288, out_features=1152, bias=True)
#             (act): GELU(0, 0.000% Params, 226.94 KMac, 0.011% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(332.06 k, 1.450% Params, 65.42 MMac, 3.105% MACs, in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#     )
#     (2): Transformer(
#       16.13 M, 70.420% Params, 544.31 MMac, 25.832% MACs,
#       (pool): Pooling(
#         172.22 k, 0.752% Params, 448.7 KMac, 0.021% MACs,
#         (conv): Conv2d(5.76 k, 0.025% Params, 282.24 KMac, 0.013% MACs, 288, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288)
#         (fc): Linear(166.46 k, 0.727% Params, 166.46 KMac, 0.008% MACs, in_features=288, out_features=576, bias=True)
#       )
#       (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (blocks): Sequential(
#         15.96 M, 69.668% Params, 543.86 MMac, 25.811% MACs,
#         (0): Block(
#           3.99 M, 17.417% Params, 135.97 MMac, 6.453% MACs,
#           (norm1): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             1.33 M, 5.805% Params, 2.94 MMac, 0.139% MACs,
#             (qkv): Linear(997.06 k, 4.354% Params, 49.85 MMac, 2.366% MACs, in_features=576, out_features=1728, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(332.35 k, 1.451% Params, 16.62 MMac, 0.789% MACs, in_features=576, out_features=576, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             2.66 M, 11.602% Params, 132.97 MMac, 6.310% MACs,
#             (fc1): Linear(1.33 M, 5.805% Params, 66.47 MMac, 3.155% MACs, in_features=576, out_features=2304, bias=True)
#             (act): GELU(0, 0.000% Params, 115.2 KMac, 0.005% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(1.33 M, 5.797% Params, 66.38 MMac, 3.150% MACs, in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (1): Block(
#           3.99 M, 17.417% Params, 135.97 MMac, 6.453% MACs,
#           (norm1): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             1.33 M, 5.805% Params, 2.94 MMac, 0.139% MACs,
#             (qkv): Linear(997.06 k, 4.354% Params, 49.85 MMac, 2.366% MACs, in_features=576, out_features=1728, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(332.35 k, 1.451% Params, 16.62 MMac, 0.789% MACs, in_features=576, out_features=576, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             2.66 M, 11.602% Params, 132.97 MMac, 6.310% MACs,
#             (fc1): Linear(1.33 M, 5.805% Params, 66.47 MMac, 3.155% MACs, in_features=576, out_features=2304, bias=True)
#             (act): GELU(0, 0.000% Params, 115.2 KMac, 0.005% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(1.33 M, 5.797% Params, 66.38 MMac, 3.150% MACs, in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (2): Block(
#           3.99 M, 17.417% Params, 135.97 MMac, 6.453% MACs,
#           (norm1): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             1.33 M, 5.805% Params, 2.94 MMac, 0.139% MACs,
#             (qkv): Linear(997.06 k, 4.354% Params, 49.85 MMac, 2.366% MACs, in_features=576, out_features=1728, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(332.35 k, 1.451% Params, 16.62 MMac, 0.789% MACs, in_features=576, out_features=576, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             2.66 M, 11.602% Params, 132.97 MMac, 6.310% MACs,
#             (fc1): Linear(1.33 M, 5.805% Params, 66.47 MMac, 3.155% MACs, in_features=576, out_features=2304, bias=True)
#             (act): GELU(0, 0.000% Params, 115.2 KMac, 0.005% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(1.33 M, 5.797% Params, 66.38 MMac, 3.150% MACs, in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (3): Block(
#           3.99 M, 17.417% Params, 135.97 MMac, 6.453% MACs,
#           (norm1): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (attn): Attention(
#             1.33 M, 5.805% Params, 2.94 MMac, 0.139% MACs,
#             (qkv): Linear(997.06 k, 4.354% Params, 49.85 MMac, 2.366% MACs, in_features=576, out_features=1728, bias=True)
#             (q_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (k_norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (attn_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (proj): Linear(332.35 k, 1.451% Params, 16.62 MMac, 0.789% MACs, in_features=576, out_features=576, bias=True)
#             (proj_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path1): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (norm2): LayerNorm(1.15 k, 0.005% Params, 28.8 KMac, 0.001% MACs, (576,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             2.66 M, 11.602% Params, 132.97 MMac, 6.310% MACs,
#             (fc1): Linear(1.33 M, 5.805% Params, 66.47 MMac, 3.155% MACs, in_features=576, out_features=2304, bias=True)
#             (act): GELU(0, 0.000% Params, 115.2 KMac, 0.005% MACs, approximate='none')
#             (drop1): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#             (norm): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#             (fc2): Linear(1.33 M, 5.797% Params, 66.38 MMac, 3.150% MACs, in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#           )
#           (ls2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (drop_path2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm(1.15 k, 0.005% Params, 576.0 Mac, 0.000% MACs, (576,), eps=1e-06, elementwise_affine=True)
#   (head_drop): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.0, inplace=False)
#   (head): Linear(16.73 k, 0.073% Params, 16.73 KMac, 0.001% MACs, in_features=576, out_features=29, bias=True)
# )
# FLOPs: 2.11 GMac
# Number of parameters: 22.9 M

# %%
from fvcore.nn import FlopCountAnalysis, parameter_count_table

# Use the trained PiT model
input_tensor = torch.randn(1, 3, 224, 224).to(device)  # Batch size of 1, image size 224x224

# Compute FLOPs and parameter count
flops = FlopCountAnalysis(model, input_tensor)
print(f"Total FLOPs for PiT: {flops.total() / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

# Parameter count
print("Model Parameters:")
print(parameter_count_table(model))
# Out:
# Total FLOPs for PiT: 2.42 GFLOPs
# Model Parameters:
# | name                       | #elements or shape   |
# |:---------------------------|:---------------------|
# | model                      | 22.9M                |
# |  pos_embed                 |  (1, 144, 27, 27)    |
# |  cls_token                 |  (1, 1, 144)         |
# |  patch_embed               |  0.1M                |
# |   patch_embed.conv         |   0.1M               |
# |    patch_embed.conv.weight |    (144, 3, 16, 16)  |
# |    patch_embed.conv.bias   |    (144,)            |
# |  transformers              |  22.7M               |
# |   transformers.0           |   0.5M               |
# |    transformers.0.blocks   |    0.5M              |
# |   transformers.1           |   6.0M               |
# |    transformers.1.pool     |    44.6K             |
# |    transformers.1.blocks   |    6.0M              |
# |   transformers.2           |   16.1M              |
# |    transformers.2.pool     |    0.2M              |
# |    transformers.2.blocks   |    16.0M             |
# |  norm                      |  1.2K                |
# |   norm.weight              |   (576,)             |
# |   norm.bias                |   (576,)             |
# |  head                      |  16.7K               |
# |   head.weight              |   (29, 576)          |
# |   head.bias                |   (29,)              |

# %%
# Use CUDA events for precise GPU timing
start_event = torch.cuda.Event(enable_timing=True)
end_event = torch.cuda.Event(enable_timing=True)

# Input batch size of 32 for processing speed analysis
batch_size = 32
input_tensor = torch.randn(batch_size, 3, 224, 224).to(device)  # Move input to GPU

# Measure processing time
model.eval()
start_event.record()
with torch.no_grad():
    for _ in range(10):  # Run multiple iterations for reliable results
        output = model(input_tensor)
end_event.record()

torch.cuda.synchronize()  # Wait for all operations to finish
elapsed_time = start_event.elapsed_time(end_event) / 10  # Average time in milliseconds
print(f"Average processing time per batch on GPU: {elapsed_time:.2f} ms")
time_per_image = elapsed_time / batch_size
print(f"Average processing time per image on GPU: {time_per_image:.2f} ms")
# Out:
# Average processing time per batch on GPU: 40.92 ms
# Average processing time per image on GPU: 1.28 ms

# %%
import time
# Move model and input to CPU
model = model.to('cpu')
input_tensor = input_tensor.to('cpu')

# Timing using CPU
start_time = time.time()
with torch.no_grad():
    for _ in range(10):
        output = model(input_tensor)
end_time = time.time()

cpu_time_per_batch = (end_time - start_time) / 10
print(f"Average processing time per batch on CPU: {cpu_time_per_batch:.2f} seconds")
cpu_time_per_image = cpu_time_per_batch / batch_size
print(f"Average processing time per image on CPU: {cpu_time_per_image:.2f} ms")
# Out:
# Average processing time per batch on CPU: 1.33 seconds
# Average processing time per image on CPU: 0.04 ms

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set device (GPU if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move model to the device
model = model.to(device)

# Ensure input tensor is on the same device
input_tensor = input_tensor.to(device)


# Function to evaluate and collect predictions
def collect_predictions(model, test_loader):
    model.eval()
    all_preds, all_labels, all_images = [], [], []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = outputs.max(1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_images.extend(inputs.cpu().numpy())
    return np.array(all_images), np.array(all_labels), np.array(all_preds)

# Collect predictions
images, labels, preds = collect_predictions(model, test_loader)

# Identify correct and incorrect predictions
correct_indices = np.where(labels == preds)[0]
incorrect_indices = np.where(labels != preds)[0]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to display examples
def display_examples(images, labels, preds, indices, class_names, title, num_examples=5):
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(indices[:num_examples]):
        plt.subplot(1, num_examples, i + 1)
        img = images[idx].transpose(1, 2, 0)  # Convert to HWC format
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])  # Unnormalize
        img = np.clip(img, 0, 1)
        plt.imshow(img)
        pred_label = class_names[preds[idx]]
        true_label = class_names[labels[idx]]
        color = "green" if pred_label == true_label else "red"
        plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# %%
# Display 5 correct predictions
display_examples(images, labels, preds, correct_indices, test_dataset.classes, "Correctly Identified Examples", num_examples=5)

# %%
# Display 5 incorrect predictions
display_examples(images, labels, preds, incorrect_indices, test_dataset.classes, "Wrongly Identified Examples", num_examples=5)

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np

# Function to group indices by label
def group_indices_by_label(labels, indices):
    label_dict = defaultdict(list)
    for idx in indices:
        label_dict[labels[idx]].append(idx)
    return label_dict

# Function to select diverse examples
def select_diverse_examples(grouped_indices, num_examples=5):
    selected_indices = []
    for label, idx_list in grouped_indices.items():
        if len(selected_indices) < num_examples:
            selected_indices.extend(idx_list[:1])  # Take one example per label
    return selected_indices[:num_examples]

# Function to display examples
def display_diverse_examples(images, labels, preds, indices, class_names, title, num_examples=5):
    grouped_indices = group_indices_by_label(labels, indices)  # Group by true label
    selected_indices = select_diverse_examples(grouped_indices, num_examples=num_examples)  # Select diverse examples

    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(selected_indices):
        plt.subplot(1, num_examples, i + 1)
        img = images[idx].transpose(1, 2, 0)  # Convert to HWC format
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])  # Unnormalize
        img = np.clip(img, 0, 1)
        plt.imshow(img)
        pred_label = class_names[preds[idx]]
        true_label = class_names[labels[idx]]
        color = "green" if pred_label == true_label else "red"
        plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# %%
# Display diverse correct predictions
display_diverse_examples(images, labels, preds, correct_indices, test_dataset.classes, "Correctly Identified Examples (Diverse)", num_examples=5)

# %%
# Display diverse incorrect predictions
display_diverse_examples(images, labels, preds, incorrect_indices, test_dataset.classes, "Wrongly Identified Examples (Diverse)", num_examples=5)
