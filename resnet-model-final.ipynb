# %%
import os

# Data Paths
source_path = "/kaggle/input/plant-village-dataset-updated"
destination_path = "/kaggle/working/renamed_dataset"

# Create directories for Train, Val, Test
for split in ['Train', 'Val', 'Test']:
    os.makedirs(os.path.join(destination_path, split), exist_ok = True)

# %%
import shutil

# Function to rename and move folders
def rename_and_merge(source_path, destination_path):
    for plant in os.listdir(source_path):  # Loop through plants (e.g., Apple, Bell Pepper)
        plant_path = os.path.join(source_path, plant)
        if os.path.isdir(plant_path):
            for split in ['Train', 'Val', 'Test']:
                split_path = os.path.join(plant_path, split)
                if os.path.isdir(split_path):
                    for condition in os.listdir(split_path):  # E.g., Healthy, Apple Scab
                        condition_path = os.path.join(split_path, condition)
                        if os.path.isdir(condition_path) and not condition.startswith('.'):  # Ignore hidden dirs
                            # Create a new folder name with plant name
                            if condition.lower() == "healthy":
                                new_folder_name = f"{plant}_Healthy"
                            else:
                                new_folder_name = f"{plant}_{condition.replace(' ', '_')}"
                            
                            # Create destination folder
                            target_folder = os.path.join(destination_path, split, new_folder_name)
                            os.makedirs(target_folder, exist_ok=True)
                            
                            # Move all images to the renamed folder
                            for img in os.listdir(condition_path):
                                src = os.path.join(condition_path, img)
                                dest = os.path.join(target_folder, img)
                                if os.path.isfile(src):  # Ensure src is a file
                                    shutil.copy(src, dest)

# Rename and merge
rename_and_merge(source_path, destination_path)
print("Dataset reorganized and renamed successfully!")
# Out:
# Dataset reorganized and renamed successfully!

# %%
# Debugging: Check structure to ensure folders are correctly populated
for split in ['Train', 'Val', 'Test']:
    split_path = os.path.join(destination_path, split)
    print(f"\nChecking structure for {split} directory:")
    for root, dirs, files in os.walk(split_path):
        print(f"Directory: {root}, Subdirectories: {dirs}, Files: {len(files)}")
# Out:
# Checking structure for Train directory:
# Directory: /kaggle/working/renamed_dataset/Train, Subdirectories: ['Apple_Healthy', 'Corn (Maize)_Healthy', 'Apple_Black_Rot', 'Tomato_Late_Blight', 'Grape_Leaf_Blight', 'Bell Pepper_Healthy', 'Cherry_Healthy', 'Peach_Healthy', 'Tomato_Yellow_Leaf_Curl_Virus', 'Potato_Healthy', 'Bell Pepper_Bacterial_Spot', 'Cherry_Powdery_Mildew', 'Tomato_Septoria_Leaf_Spot', 'Corn (Maize)_Northern_Leaf_Blight', 'Grape_Black_Rot', 'Apple_Apple_Scab', 'Potato_Early_Blight', 'Apple_Cedar_Apple_Rust', 'Tomato_Early_Blight', 'Corn (Maize)_Common_Rust_', 'Corn (Maize)_Cercospora_Leaf_Spot', 'Peach_Bacterial_Spot', 'Tomato_Bacterial_Spot', 'Strawberry_Healthy', 'Potato_Late_Blight', 'Tomato_Healthy', 'Grape_Healthy', 'Strawberry_Leaf_Scorch', 'Grape_Esca_(Black_Measles)'], Files: 0
# Directory: /kaggle/working/renamed_dataset/Train/Apple_Healthy, Subdirectories: [], Files: 2008
# Directory: /kaggle/working/renamed_dataset/Train/Corn (Maize)_Healthy, Subdirectories: [], Files: 1859
# Directory: /kaggle/working/renamed_dataset/Train/Apple_Black_Rot, Subdirectories: [], Files: 1987
# Directory: /kaggle/working/renamed_dataset/Train/Tomato_Late_Blight, Subdirectories: [], Files: 1851
# Directory: /kaggle/working/renamed_dataset/Train/Grape_Leaf_Blight, Subdirectories: [], Files: 1722
# Directory: /kaggle/working/renamed_dataset/Train/Bell Pepper_Healthy, Subdirectories: [], Files: 1988
# Directory: /kaggle/working/renamed_dataset/Train/Cherry_Healthy, Subdirectories: [], Files: 1826
# Directory: /kaggle/working/renamed_dataset/Train/Peach_Healthy, Subdirectories: [], Files: 1728
# Directory: /kaggle/working/renamed_dataset/Train/Tomato_Yellow_Leaf_Curl_Virus, Subdirectories: [], Files: 1961
# Directory: /kaggle/working/renamed_dataset/Train/Potato_Healthy, Subdirectories: [], Files: 1824
# Directory: /kaggle/working/renamed_dataset/Train/Bell Pepper_Bacterial_Spot, Subdirectories: [], Files: 1913
# Directory: /kaggle/working/renamed_dataset/Train/Cherry_Powdery_Mildew, Subdirectories: [], Files: 1683
# Directory: /kaggle/working/renamed_dataset/Train/Tomato_Septoria_Leaf_Spot, Subdirectories: [], Files: 1745
# Directory: /kaggle/working/renamed_dataset/Train/Corn (Maize)_Northern_Leaf_Blight, Subdirectories: [], Files: 1908
# Directory: /kaggle/working/renamed_dataset/Train/Grape_Black_Rot, Subdirectories: [], Files: 1888
# Directory: /kaggle/working/renamed_dataset/Train/Apple_Apple_Scab, Subdirectories: [], Files: 2016
# Directory: /kaggle/working/renamed_dataset/Train/Potato_Early_Blight, Subdirectories: [], Files: 1939
# Directory: /kaggle/working/renamed_dataset/Train/Apple_Cedar_Apple_Rust, Subdirectories: [], Files: 1760
# Directory: /kaggle/working/renamed_dataset/Train/Tomato_Early_Blight, Subdirectories: [], Files: 1920
# Directory: /kaggle/working/renamed_dataset/Train/Corn (Maize)_Common_Rust_, Subdirectories: [], Files: 1907
# Directory: /kaggle/working/renamed_dataset/Train/Corn (Maize)_Cercospora_Leaf_Spot, Subdirectories: [], Files: 1642
# Directory: /kaggle/working/renamed_dataset/Train/Peach_Bacterial_Spot, Subdirectories: [], Files: 1838
# Directory: /kaggle/working/renamed_dataset/Train/Tomato_Bacterial_Spot, Subdirectories: [], Files: 1702
# Directory: /kaggle/working/renamed_dataset/Train/Strawberry_Healthy, Subdirectories: [], Files: 1824
# Directory: /kaggle/working/renamed_dataset/Train/Potato_Late_Blight, Subdirectories: [], Files: 1939
# Directory: /kaggle/working/renamed_dataset/Train/Tomato_Healthy, Subdirectories: [], Files: 1926
# Directory: /kaggle/working/renamed_dataset/Train/Grape_Healthy, Subdirectories: [], Files: 1692
# Directory: /kaggle/working/renamed_dataset/Train/Strawberry_Leaf_Scorch, Subdirectories: [], Files: 1774
# Directory: /kaggle/working/renamed_dataset/Train/Grape_Esca_(Black_Measles), Subdirectories: [], Files: 1920
#
# Checking structure for Val directory:
# Directory: /kaggle/working/renamed_dataset/Val, Subdirectories: ['Apple_Healthy', 'Corn (Maize)_Healthy', 'Apple_Black_Rot', 'Tomato_Late_Blight', 'Grape_Leaf_Blight', 'Bell Pepper_Healthy', 'Cherry_Healthy', 'Peach_Healthy', 'Tomato_Yellow_Leaf_Curl_Virus', 'Potato_Healthy', 'Bell Pepper_Bacterial_Spot', 'Cherry_Powdery_Mildew', 'Tomato_Septoria_Leaf_Spot', 'Corn (Maize)_Northern_Leaf_Blight', 'Grape_Black_Rot', 'Apple_Apple_Scab', 'Potato_Early_Blight', 'Apple_Cedar_Apple_Rust', 'Tomato_Early_Blight', 'Corn (Maize)_Common_Rust_', 'Corn (Maize)_Cercospora_Leaf_Spot', 'Peach_Bacterial_Spot', 'Tomato_Bacterial_Spot', 'Strawberry_Healthy', 'Potato_Late_Blight', 'Tomato_Healthy', 'Grape_Healthy', 'Strawberry_Leaf_Scorch', 'Grape_Esca_(Black_Measles)'], Files: 0
# Directory: /kaggle/working/renamed_dataset/Val/Apple_Healthy, Subdirectories: [], Files: 451
# Directory: /kaggle/working/renamed_dataset/Val/Corn (Maize)_Healthy, Subdirectories: [], Files: 418
# Directory: /kaggle/working/renamed_dataset/Val/Apple_Black_Rot, Subdirectories: [], Files: 447
# Directory: /kaggle/working/renamed_dataset/Val/Tomato_Late_Blight, Subdirectories: [], Files: 416
# Directory: /kaggle/working/renamed_dataset/Val/Grape_Leaf_Blight, Subdirectories: [], Files: 387
# Directory: /kaggle/working/renamed_dataset/Val/Bell Pepper_Healthy, Subdirectories: [], Files: 447
# Directory: /kaggle/working/renamed_dataset/Val/Cherry_Healthy, Subdirectories: [], Files: 410
# Directory: /kaggle/working/renamed_dataset/Val/Peach_Healthy, Subdirectories: [], Files: 388
# Directory: /kaggle/working/renamed_dataset/Val/Tomato_Yellow_Leaf_Curl_Virus, Subdirectories: [], Files: 441
# Directory: /kaggle/working/renamed_dataset/Val/Potato_Healthy, Subdirectories: [], Files: 410
# Directory: /kaggle/working/renamed_dataset/Val/Bell Pepper_Bacterial_Spot, Subdirectories: [], Files: 430
# Directory: /kaggle/working/renamed_dataset/Val/Cherry_Powdery_Mildew, Subdirectories: [], Files: 378
# Directory: /kaggle/working/renamed_dataset/Val/Tomato_Septoria_Leaf_Spot, Subdirectories: [], Files: 392
# Directory: /kaggle/working/renamed_dataset/Val/Corn (Maize)_Northern_Leaf_Blight, Subdirectories: [], Files: 429
# Directory: /kaggle/working/renamed_dataset/Val/Grape_Black_Rot, Subdirectories: [], Files: 424
# Directory: /kaggle/working/renamed_dataset/Val/Apple_Apple_Scab, Subdirectories: [], Files: 453
# Directory: /kaggle/working/renamed_dataset/Val/Potato_Early_Blight, Subdirectories: [], Files: 436
# Directory: /kaggle/working/renamed_dataset/Val/Apple_Cedar_Apple_Rust, Subdirectories: [], Files: 396
# Directory: /kaggle/working/renamed_dataset/Val/Tomato_Early_Blight, Subdirectories: [], Files: 432
# Directory: /kaggle/working/renamed_dataset/Val/Corn (Maize)_Common_Rust_, Subdirectories: [], Files: 429
# Directory: /kaggle/working/renamed_dataset/Val/Corn (Maize)_Cercospora_Leaf_Spot, Subdirectories: [], Files: 369
# Directory: /kaggle/working/renamed_dataset/Val/Peach_Bacterial_Spot, Subdirectories: [], Files: 413
# Directory: /kaggle/working/renamed_dataset/Val/Tomato_Bacterial_Spot, Subdirectories: [], Files: 382
# Directory: /kaggle/working/renamed_dataset/Val/Strawberry_Healthy, Subdirectories: [], Files: 410
# Directory: /kaggle/working/renamed_dataset/Val/Potato_Late_Blight, Subdirectories: [], Files: 436
# Directory: /kaggle/working/renamed_dataset/Val/Tomato_Healthy, Subdirectories: [], Files: 432
# Directory: /kaggle/working/renamed_dataset/Val/Grape_Healthy, Subdirectories: [], Files: 380
# Directory: /kaggle/working/renamed_dataset/Val/Strawberry_Leaf_Scorch, Subdirectories: [], Files: 399
# Directory: /kaggle/working/renamed_dataset/Val/Grape_Esca_(Black_Measles), Subdirectories: [], Files: 432
#
# Checking structure for Test directory:
# Directory: /kaggle/working/renamed_dataset/Test, Subdirectories: ['Apple_Healthy', 'Corn (Maize)_Healthy', 'Apple_Black_Rot', 'Tomato_Late_Blight', 'Grape_Leaf_Blight', 'Bell Pepper_Healthy', 'Cherry_Healthy', 'Peach_Healthy', 'Tomato_Yellow_Leaf_Curl_Virus', 'Potato_Healthy', 'Bell Pepper_Bacterial_Spot', 'Cherry_Powdery_Mildew', 'Tomato_Septoria_Leaf_Spot', 'Corn (Maize)_Northern_Leaf_Blight', 'Grape_Black_Rot', 'Apple_Apple_Scab', 'Potato_Early_Blight', 'Apple_Cedar_Apple_Rust', 'Tomato_Early_Blight', 'Corn (Maize)_Common_Rust_', 'Corn (Maize)_Cercospora_Leaf_Spot', 'Peach_Bacterial_Spot', 'Tomato_Bacterial_Spot', 'Strawberry_Healthy', 'Potato_Late_Blight', 'Tomato_Healthy', 'Grape_Healthy', 'Strawberry_Leaf_Scorch', 'Grape_Esca_(Black_Measles)'], Files: 0
# Directory: /kaggle/working/renamed_dataset/Test/Apple_Healthy, Subdirectories: [], Files: 51
# Directory: /kaggle/working/renamed_dataset/Test/Corn (Maize)_Healthy, Subdirectories: [], Files: 47
# Directory: /kaggle/working/renamed_dataset/Test/Apple_Black_Rot, Subdirectories: [], Files: 50
# Directory: /kaggle/working/renamed_dataset/Test/Tomato_Late_Blight, Subdirectories: [], Files: 47
# Directory: /kaggle/working/renamed_dataset/Test/Grape_Leaf_Blight, Subdirectories: [], Files: 43
# Directory: /kaggle/working/renamed_dataset/Test/Bell Pepper_Healthy, Subdirectories: [], Files: 50
# Directory: /kaggle/working/renamed_dataset/Test/Cherry_Healthy, Subdirectories: [], Files: 46
# Directory: /kaggle/working/renamed_dataset/Test/Peach_Healthy, Subdirectories: [], Files: 44
# Directory: /kaggle/working/renamed_dataset/Test/Tomato_Yellow_Leaf_Curl_Virus, Subdirectories: [], Files: 49
# Directory: /kaggle/working/renamed_dataset/Test/Potato_Healthy, Subdirectories: [], Files: 46
# Directory: /kaggle/working/renamed_dataset/Test/Bell Pepper_Bacterial_Spot, Subdirectories: [], Files: 48
# Directory: /kaggle/working/renamed_dataset/Test/Cherry_Powdery_Mildew, Subdirectories: [], Files: 43
# Directory: /kaggle/working/renamed_dataset/Test/Tomato_Septoria_Leaf_Spot, Subdirectories: [], Files: 44
# Directory: /kaggle/working/renamed_dataset/Test/Corn (Maize)_Northern_Leaf_Blight, Subdirectories: [], Files: 48
# Directory: /kaggle/working/renamed_dataset/Test/Grape_Black_Rot, Subdirectories: [], Files: 48
# Directory: /kaggle/working/renamed_dataset/Test/Apple_Apple_Scab, Subdirectories: [], Files: 51
# Directory: /kaggle/working/renamed_dataset/Test/Potato_Early_Blight, Subdirectories: [], Files: 49
# Directory: /kaggle/working/renamed_dataset/Test/Apple_Cedar_Apple_Rust, Subdirectories: [], Files: 44
# Directory: /kaggle/working/renamed_dataset/Test/Tomato_Early_Blight, Subdirectories: [], Files: 48
# Directory: /kaggle/working/renamed_dataset/Test/Corn (Maize)_Common_Rust_, Subdirectories: [], Files: 48
# Directory: /kaggle/working/renamed_dataset/Test/Corn (Maize)_Cercospora_Leaf_Spot, Subdirectories: [], Files: 41
# Directory: /kaggle/working/renamed_dataset/Test/Peach_Bacterial_Spot, Subdirectories: [], Files: 46
# Directory: /kaggle/working/renamed_dataset/Test/Tomato_Bacterial_Spot, Subdirectories: [], Files: 43
# Directory: /kaggle/working/renamed_dataset/Test/Strawberry_Healthy, Subdirectories: [], Files: 46
# Directory: /kaggle/working/renamed_dataset/Test/Potato_Late_Blight, Subdirectories: [], Files: 49
# Directory: /kaggle/working/renamed_dataset/Test/Tomato_Healthy, Subdirectories: [], Files: 49
# Directory: /kaggle/working/renamed_dataset/Test/Grape_Healthy, Subdirectories: [], Files: 43
# Directory: /kaggle/working/renamed_dataset/Test/Strawberry_Leaf_Scorch, Subdirectories: [], Files: 45
# Directory: /kaggle/working/renamed_dataset/Test/Grape_Esca_(Black_Measles), Subdirectories: [], Files: 48

# %%
from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import DataLoader

# Paths for the renamed dataset
TRAIN_PATH = os.path.join(destination_path, 'Train')
VAL_PATH = os.path.join(destination_path, 'Val')
TEST_PATH = os.path.join(destination_path, 'Test')

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load datasets
train_dataset = ImageFolder(TRAIN_PATH, transform=transform)
val_dataset = ImageFolder(VAL_PATH, transform=transform)
test_dataset = ImageFolder(TEST_PATH, transform=transform)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Print class names
print(f"Classes: {train_dataset.classes}")
print(f"Number of classes: {len(train_dataset.classes)}")
print(f"Training samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")
# Out:
# Classes: ['Apple_Apple_Scab', 'Apple_Black_Rot', 'Apple_Cedar_Apple_Rust', 'Apple_Healthy', 'Bell Pepper_Bacterial_Spot', 'Bell Pepper_Healthy', 'Cherry_Healthy', 'Cherry_Powdery_Mildew', 'Corn (Maize)_Cercospora_Leaf_Spot', 'Corn (Maize)_Common_Rust_', 'Corn (Maize)_Healthy', 'Corn (Maize)_Northern_Leaf_Blight', 'Grape_Black_Rot', 'Grape_Esca_(Black_Measles)', 'Grape_Healthy', 'Grape_Leaf_Blight', 'Peach_Bacterial_Spot', 'Peach_Healthy', 'Potato_Early_Blight', 'Potato_Healthy', 'Potato_Late_Blight', 'Strawberry_Healthy', 'Strawberry_Leaf_Scorch', 'Tomato_Bacterial_Spot', 'Tomato_Early_Blight', 'Tomato_Healthy', 'Tomato_Late_Blight', 'Tomato_Septoria_Leaf_Spot', 'Tomato_Yellow_Leaf_Curl_Virus']
# Number of classes: 29
# Training samples: 53690
# Validation samples: 12067
# Test samples: 1354

# %%
import timm
import torch
from torch import nn

# Load the ResNet model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = timm.create_model('resnet50', pretrained=True, num_classes=len(train_dataset.classes))
model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)

print("Model loaded successfully!")
# Out:
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Model loaded successfully!

# %%
def train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs=10):
    for epoch in range(epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, preds = outputs.max(1)
            correct += preds.eq(labels).sum().item()
            total += labels.size(0)

        train_accuracy = 100 * correct / total
        print(f"Epoch {epoch+1}: Train Loss = {running_loss:.4f}, Train Accuracy = {train_accuracy:.2f}%")

        # Validation phase
        model.eval()
        val_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, preds = outputs.max(1)
                correct += preds.eq(labels).sum().item()
                total += labels.size(0)

        val_accuracy = 100 * correct / total
        print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")

# Train the model
train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs=10)
# Out:
# Epoch 1: Train Loss = 272.3394, Train Accuracy = 95.44%
# Validation Loss: 13.1313, Validation Accuracy: 98.87%
# Epoch 2: Train Loss = 61.4913, Train Accuracy = 98.91%
# Validation Loss: 26.5330, Validation Accuracy: 97.91%
# Epoch 3: Train Loss = 44.7601, Train Accuracy = 99.18%
# Validation Loss: 17.1163, Validation Accuracy: 98.62%
# Epoch 4: Train Loss = 37.4963, Train Accuracy = 99.28%
# Validation Loss: 7.5498, Validation Accuracy: 99.31%
# Epoch 5: Train Loss = 33.6762, Train Accuracy = 99.38%
# Validation Loss: 18.0881, Validation Accuracy: 98.72%
# Epoch 6: Train Loss = 27.5254, Train Accuracy = 99.45%
# Validation Loss: 21.6612, Validation Accuracy: 98.18%
# Epoch 7: Train Loss = 23.6213, Train Accuracy = 99.55%
# Validation Loss: 7.1359, Validation Accuracy: 99.47%
# Epoch 8: Train Loss = 17.8070, Train Accuracy = 99.66%
# Validation Loss: 13.8975, Validation Accuracy: 98.93%
# Epoch 9: Train Loss = 22.8100, Train Accuracy = 99.56%
# Validation Loss: 15.5383, Validation Accuracy: 98.78%
# Epoch 10: Train Loss = 18.3606, Train Accuracy = 99.66%
# Validation Loss: 4.9685, Validation Accuracy: 99.67%

# %%
torch.save(model.state_dict(), '/kaggle/working/resnet_model_final.pth')
print("Model saved at /kaggle/working/resnet_model_final.pth")
# Out:
# Model saved at /kaggle/working/resnet_model_final.pth

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

def evaluate_model(model, test_loader):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = outputs.max(1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Generate classification report
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=test_dataset.classes))

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(12, 8))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=test_dataset.classes, yticklabels=test_dataset.classes, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Evaluate the model
evaluate_model(model, test_loader)
# Out:
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                  Apple_Apple_Scab       1.00      0.98      0.99        51
#                   Apple_Black_Rot       1.00      1.00      1.00        50
#            Apple_Cedar_Apple_Rust       1.00      1.00      1.00        44
#                     Apple_Healthy       0.98      1.00      0.99        51
#        Bell Pepper_Bacterial_Spot       1.00      1.00      1.00        48
#               Bell Pepper_Healthy       1.00      1.00      1.00        50
#                    Cherry_Healthy       1.00      1.00      1.00        46
#             Cherry_Powdery_Mildew       1.00      1.00      1.00        43
# Corn (Maize)_Cercospora_Leaf_Spot       1.00      1.00      1.00        41
#         Corn (Maize)_Common_Rust_       1.00      1.00      1.00        48
#              Corn (Maize)_Healthy       1.00      1.00      1.00        47
# Corn (Maize)_Northern_Leaf_Blight       1.00      1.00      1.00        48
#                   Grape_Black_Rot       1.00      1.00      1.00        48
#        Grape_Esca_(Black_Measles)       1.00      1.00      1.00        48
#                     Grape_Healthy       1.00      1.00      1.00        43
#                 Grape_Leaf_Blight       1.00      1.00      1.00        43
#              Peach_Bacterial_Spot       1.00      1.00      1.00        46
#                     Peach_Healthy       1.00      1.00      1.00        44
#               Potato_Early_Blight       1.00      1.00      1.00        49
#                    Potato_Healthy       1.00      1.00      1.00        46
#                Potato_Late_Blight       1.00      1.00      1.00        49
#                Strawberry_Healthy       1.00      1.00      1.00        46
#            Strawberry_Leaf_Scorch       1.00      1.00      1.00        45
#             Tomato_Bacterial_Spot       1.00      0.98      0.99        43
#               Tomato_Early_Blight       0.98      1.00      0.99        48
#                    Tomato_Healthy       1.00      1.00      1.00        49
#                Tomato_Late_Blight       0.98      1.00      0.99        47
#         Tomato_Septoria_Leaf_Spot       1.00      0.98      0.99        44
#     Tomato_Yellow_Leaf_Curl_Virus       1.00      1.00      1.00        49
#
#                          accuracy                           1.00      1354
#                         macro avg       1.00      1.00      1.00      1354
#                      weighted avg       1.00      1.00      1.00      1354

# %%
# !pip install ptflops
# Out:
# Collecting ptflops
#   Downloading ptflops-0.7.4-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch>=2.0 in /opt/conda/lib/python3.10/site-packages (from ptflops) (2.4.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2.0->ptflops) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.0->ptflops) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.0->ptflops) (1.3.0)
# Downloading ptflops-0.7.4-py3-none-any.whl (19 kB)
# Installing collected packages: ptflops
# Successfully installed ptflops-0.7.4

# %%
from ptflops import get_model_complexity_info

# Input size for the ResNet model (C=3, H=W=224 for ImageNet-sized images)
input_size = (3, 224, 224)

# Calculate FLOPs and parameters
with torch.no_grad():
    macs, params = get_model_complexity_info(model, input_size, as_strings=True, verbose=True)
    print(f"FLOPs: {macs}")
    print(f"Number of parameters: {params}")
# Out:
# Warning: module Identity is treated as a zero-op.
# Warning: module Bottleneck is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module SelectAdaptivePool2d is treated as a zero-op.
# Warning: module ResNet is treated as a zero-op.
# ResNet(
#   23.57 M, 100.000% Params, 4.12 GMac, 99.746% MACs,
#   (conv1): Conv2d(9.41 k, 0.040% Params, 118.01 MMac, 2.857% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.039% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#   (maxpool): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.019% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     215.81 k, 0.916% Params, 680.39 MMac, 16.472% MACs,
#     (0): Bottleneck(
#       75.01 k, 0.318% Params, 236.43 MMac, 5.724% MACs,
#       (conv1): Conv2d(4.1 k, 0.017% Params, 12.85 MMac, 0.311% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (conv2): Conv2d(36.86 k, 0.156% Params, 115.61 MMac, 2.799% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(16.38 k, 0.070% Params, 51.38 MMac, 1.244% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#       (downsample): Sequential(
#         16.9 k, 0.072% Params, 52.99 MMac, 1.283% MACs,
#         (0): Conv2d(16.38 k, 0.070% Params, 51.38 MMac, 1.244% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       70.4 k, 0.299% Params, 221.98 MMac, 5.374% MACs,
#       (conv1): Conv2d(16.38 k, 0.070% Params, 51.38 MMac, 1.244% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (conv2): Conv2d(36.86 k, 0.156% Params, 115.61 MMac, 2.799% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(16.38 k, 0.070% Params, 51.38 MMac, 1.244% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       70.4 k, 0.299% Params, 221.98 MMac, 5.374% MACs,
#       (conv1): Conv2d(16.38 k, 0.070% Params, 51.38 MMac, 1.244% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (conv2): Conv2d(36.86 k, 0.156% Params, 115.61 MMac, 2.799% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(16.38 k, 0.070% Params, 51.38 MMac, 1.244% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     1.22 M, 5.175% Params, 1.04 GMac, 25.095% MACs,
#     (0): Bottleneck(
#       379.39 k, 1.610% Params, 376.02 MMac, 9.104% MACs,
#       (conv1): Conv2d(32.77 k, 0.139% Params, 102.76 MMac, 2.488% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 401.41 KMac, 0.010% MACs, inplace=True)
#       (conv2): Conv2d(147.46 k, 0.626% Params, 115.61 MMac, 2.799% MACs, 128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(65.54 k, 0.278% Params, 51.38 MMac, 1.244% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 401.41 KMac, 0.010% MACs, inplace=True)
#       (downsample): Sequential(
#         132.1 k, 0.561% Params, 103.56 MMac, 2.507% MACs,
#         (0): Conv2d(131.07 k, 0.556% Params, 102.76 MMac, 2.488% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       280.06 k, 1.188% Params, 220.17 MMac, 5.330% MACs,
#       (conv1): Conv2d(65.54 k, 0.278% Params, 51.38 MMac, 1.244% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (conv2): Conv2d(147.46 k, 0.626% Params, 115.61 MMac, 2.799% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(65.54 k, 0.278% Params, 51.38 MMac, 1.244% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 401.41 KMac, 0.010% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       280.06 k, 1.188% Params, 220.17 MMac, 5.330% MACs,
#       (conv1): Conv2d(65.54 k, 0.278% Params, 51.38 MMac, 1.244% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (conv2): Conv2d(147.46 k, 0.626% Params, 115.61 MMac, 2.799% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(65.54 k, 0.278% Params, 51.38 MMac, 1.244% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 401.41 KMac, 0.010% MACs, inplace=True)
#     )
#     (3): Bottleneck(
#       280.06 k, 1.188% Params, 220.17 MMac, 5.330% MACs,
#       (conv1): Conv2d(65.54 k, 0.278% Params, 51.38 MMac, 1.244% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (conv2): Conv2d(147.46 k, 0.626% Params, 115.61 MMac, 2.799% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(65.54 k, 0.278% Params, 51.38 MMac, 1.244% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 401.41 KMac, 0.010% MACs, inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     7.1 M, 30.119% Params, 1.47 GMac, 35.604% MACs,
#     (0): Bottleneck(
#       1.51 M, 6.418% Params, 374.26 MMac, 9.061% MACs,
#       (conv1): Conv2d(131.07 k, 0.556% Params, 102.76 MMac, 2.488% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.010% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 2.503% Params, 115.61 MMac, 2.799% MACs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.009% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#       (downsample): Sequential(
#         526.34 k, 2.233% Params, 103.16 MMac, 2.498% MACs,
#         (0): Conv2d(524.29 k, 2.225% Params, 102.76 MMac, 2.488% MACs, 512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2.05 k, 0.009% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       1.12 M, 4.740% Params, 219.27 MMac, 5.309% MACs,
#       (conv1): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 2.503% Params, 115.61 MMac, 2.799% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.009% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       1.12 M, 4.740% Params, 219.27 MMac, 5.309% MACs,
#       (conv1): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 2.503% Params, 115.61 MMac, 2.799% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.009% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#     )
#     (3): Bottleneck(
#       1.12 M, 4.740% Params, 219.27 MMac, 5.309% MACs,
#       (conv1): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 2.503% Params, 115.61 MMac, 2.799% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.009% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#     )
#     (4): Bottleneck(
#       1.12 M, 4.740% Params, 219.27 MMac, 5.309% MACs,
#       (conv1): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 2.503% Params, 115.61 MMac, 2.799% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.009% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#     )
#     (5): Bottleneck(
#       1.12 M, 4.740% Params, 219.27 MMac, 5.309% MACs,
#       (conv1): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 2.503% Params, 115.61 MMac, 2.799% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 50.18 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(262.14 k, 1.112% Params, 51.38 MMac, 1.244% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.009% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     14.96 M, 63.497% Params, 811.02 MMac, 19.635% MACs,
#     (0): Bottleneck(
#       6.04 M, 25.627% Params, 373.38 MMac, 9.040% MACs,
#       (conv1): Conv2d(524.29 k, 2.225% Params, 102.76 MMac, 2.488% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (conv2): Conv2d(2.36 M, 10.011% Params, 115.61 MMac, 2.799% MACs, 512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(1.05 M, 4.449% Params, 51.38 MMac, 1.244% MACs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.017% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#       (downsample): Sequential(
#         2.1 M, 8.916% Params, 102.96 MMac, 2.493% MACs,
#         (0): Conv2d(2.1 M, 8.899% Params, 102.76 MMac, 2.488% MACs, 1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(4.1 k, 0.017% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       4.46 M, 18.935% Params, 218.82 MMac, 5.298% MACs,
#       (conv1): Conv2d(1.05 M, 4.449% Params, 51.38 MMac, 1.244% MACs, 2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#       (conv2): Conv2d(2.36 M, 10.011% Params, 115.61 MMac, 2.799% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(1.05 M, 4.449% Params, 51.38 MMac, 1.244% MACs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.017% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       4.46 M, 18.935% Params, 218.82 MMac, 5.298% MACs,
#       (conv1): Conv2d(1.05 M, 4.449% Params, 51.38 MMac, 1.244% MACs, 2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#       (conv2): Conv2d(2.36 M, 10.011% Params, 115.61 MMac, 2.799% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (act2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#       (aa): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (conv3): Conv2d(1.05 M, 4.449% Params, 51.38 MMac, 1.244% MACs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.017% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(0, 0.000% Params, 100.35 KMac, 0.002% MACs, inplace=True)
#     )
#   )
#   (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1))
#   (fc): Linear(59.42 k, 0.252% Params, 59.42 KMac, 0.001% MACs, in_features=2048, out_features=29, bias=True)
# )
# FLOPs: 4.13 GMac
# Number of parameters: 23.57 M

# %%
# !pip install fvcore
# Out:
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from fvcore) (1.26.4)
# Collecting yacs>=0.1.6 (from fvcore)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from fvcore) (6.0.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from fvcore) (4.66.4)
# Requirement already satisfied: termcolor>=1.1 in /opt/conda/lib/python3.10/site-packages (from fvcore) (2.4.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from fvcore) (10.3.0)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from fvcore) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.10/site-packages (from iopath>=0.1.7->fvcore) (4.12.2)
# Collecting portalocker (from iopath>=0.1.7->fvcore)
#   Downloading portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.0.0-py3-none-any.whl (19 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=5b81f7522a8eb71647b2224d72927df511e29af903e30a4ac15a77c9c9d6e6ab
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=3132387aea9280c34d12f72383c92683824b6f77e6c6d519a25f629af26c8e4a
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-3.0.0 yacs-0.1.8

# %%
from fvcore.nn import FlopCountAnalysis, parameter_count_table

# Use the trained ResNet model
input_tensor = torch.randn(1, 3, 224, 224).to(device)  # Batch size of 1, image size 224x224

# Compute FLOPs and parameter count
flops = FlopCountAnalysis(model, input_tensor)
print(f"Total FLOPs for ResNet: {flops.total() / 1e9:.2f} GFLOPs")  # Convert to GFLOPs

# Parameter count
print("Model Parameters:")
print(parameter_count_table(model))
# Out:
# Total FLOPs for ResNet: 4.11 GFLOPs
# Model Parameters:
# | name                   | #elements or shape   |
# |:-----------------------|:---------------------|
# | model                  | 23.6M                |
# |  conv1                 |  9.4K                |
# |   conv1.weight         |   (64, 3, 7, 7)      |
# |  bn1                   |  0.1K                |
# |   bn1.weight           |   (64,)              |
# |   bn1.bias             |   (64,)              |
# |  layer1                |  0.2M                |
# |   layer1.0             |   75.0K              |
# |    layer1.0.conv1      |    4.1K              |
# |    layer1.0.bn1        |    0.1K              |
# |    layer1.0.conv2      |    36.9K             |
# |    layer1.0.bn2        |    0.1K              |
# |    layer1.0.conv3      |    16.4K             |
# |    layer1.0.bn3        |    0.5K              |
# |    layer1.0.downsample |    16.9K             |
# |   layer1.1             |   70.4K              |
# |    layer1.1.conv1      |    16.4K             |
# |    layer1.1.bn1        |    0.1K              |
# |    layer1.1.conv2      |    36.9K             |
# |    layer1.1.bn2        |    0.1K              |
# |    layer1.1.conv3      |    16.4K             |
# |    layer1.1.bn3        |    0.5K              |
# |   layer1.2             |   70.4K              |
# |    layer1.2.conv1      |    16.4K             |
# |    layer1.2.bn1        |    0.1K              |
# |    layer1.2.conv2      |    36.9K             |
# |    layer1.2.bn2        |    0.1K              |
# |    layer1.2.conv3      |    16.4K             |
# |    layer1.2.bn3        |    0.5K              |
# |  layer2                |  1.2M                |
# |   layer2.0             |   0.4M               |
# |    layer2.0.conv1      |    32.8K             |
# |    layer2.0.bn1        |    0.3K              |
# |    layer2.0.conv2      |    0.1M              |
# |    layer2.0.bn2        |    0.3K              |
# |    layer2.0.conv3      |    65.5K             |
# |    layer2.0.bn3        |    1.0K              |
# |    layer2.0.downsample |    0.1M              |
# |   layer2.1             |   0.3M               |
# |    layer2.1.conv1      |    65.5K             |
# |    layer2.1.bn1        |    0.3K              |
# |    layer2.1.conv2      |    0.1M              |
# |    layer2.1.bn2        |    0.3K              |
# |    layer2.1.conv3      |    65.5K             |
# |    layer2.1.bn3        |    1.0K              |
# |   layer2.2             |   0.3M               |
# |    layer2.2.conv1      |    65.5K             |
# |    layer2.2.bn1        |    0.3K              |
# |    layer2.2.conv2      |    0.1M              |
# |    layer2.2.bn2        |    0.3K              |
# |    layer2.2.conv3      |    65.5K             |
# |    layer2.2.bn3        |    1.0K              |
# |   layer2.3             |   0.3M               |
# |    layer2.3.conv1      |    65.5K             |
# |    layer2.3.bn1        |    0.3K              |
# |    layer2.3.conv2      |    0.1M              |
# |    layer2.3.bn2        |    0.3K              |
# |    layer2.3.conv3      |    65.5K             |
# |    layer2.3.bn3        |    1.0K              |
# |  layer3                |  7.1M                |
# |   layer3.0             |   1.5M               |
# |    layer3.0.conv1      |    0.1M              |
# |    layer3.0.bn1        |    0.5K              |
# |    layer3.0.conv2      |    0.6M              |
# |    layer3.0.bn2        |    0.5K              |
# |    layer3.0.conv3      |    0.3M              |
# |    layer3.0.bn3        |    2.0K              |
# |    layer3.0.downsample |    0.5M              |
# |   layer3.1             |   1.1M               |
# |    layer3.1.conv1      |    0.3M              |
# |    layer3.1.bn1        |    0.5K              |
# |    layer3.1.conv2      |    0.6M              |
# |    layer3.1.bn2        |    0.5K              |
# |    layer3.1.conv3      |    0.3M              |
# |    layer3.1.bn3        |    2.0K              |
# |   layer3.2             |   1.1M               |
# |    layer3.2.conv1      |    0.3M              |
# |    layer3.2.bn1        |    0.5K              |
# |    layer3.2.conv2      |    0.6M              |
# |    layer3.2.bn2        |    0.5K              |
# |    layer3.2.conv3      |    0.3M              |
# |    layer3.2.bn3        |    2.0K              |
# |   layer3.3             |   1.1M               |
# |    layer3.3.conv1      |    0.3M              |
# |    layer3.3.bn1        |    0.5K              |
# |    layer3.3.conv2      |    0.6M              |
# |    layer3.3.bn2        |    0.5K              |
# |    layer3.3.conv3      |    0.3M              |
# |    layer3.3.bn3        |    2.0K              |
# |   layer3.4             |   1.1M               |
# |    layer3.4.conv1      |    0.3M              |
# |    layer3.4.bn1        |    0.5K              |
# |    layer3.4.conv2      |    0.6M              |
# |    layer3.4.bn2        |    0.5K              |
# |    layer3.4.conv3      |    0.3M              |
# |    layer3.4.bn3        |    2.0K              |
# |   layer3.5             |   1.1M               |
# |    layer3.5.conv1      |    0.3M              |
# |    layer3.5.bn1        |    0.5K              |
# |    layer3.5.conv2      |    0.6M              |
# |    layer3.5.bn2        |    0.5K              |
# |    layer3.5.conv3      |    0.3M              |
# |    layer3.5.bn3        |    2.0K              |
# |  layer4                |  15.0M               |
# |   layer4.0             |   6.0M               |
# |    layer4.0.conv1      |    0.5M              |
# |    layer4.0.bn1        |    1.0K              |
# |    layer4.0.conv2      |    2.4M              |
# |    layer4.0.bn2        |    1.0K              |
# |    layer4.0.conv3      |    1.0M              |
# |    layer4.0.bn3        |    4.1K              |
# |    layer4.0.downsample |    2.1M              |
# |   layer4.1             |   4.5M               |
# |    layer4.1.conv1      |    1.0M              |
# |    layer4.1.bn1        |    1.0K              |
# |    layer4.1.conv2      |    2.4M              |
# |    layer4.1.bn2        |    1.0K              |
# |    layer4.1.conv3      |    1.0M              |
# |    layer4.1.bn3        |    4.1K              |
# |   layer4.2             |   4.5M               |
# |    layer4.2.conv1      |    1.0M              |
# |    layer4.2.bn1        |    1.0K              |
# |    layer4.2.conv2      |    2.4M              |
# |    layer4.2.bn2        |    1.0K              |
# |    layer4.2.conv3      |    1.0M              |
# |    layer4.2.bn3        |    4.1K              |
# |  fc                    |  59.4K               |
# |   fc.weight            |   (29, 2048)         |
# |   fc.bias              |   (29,)              |

# %%
# Use CUDA events for precise GPU timing
start_event = torch.cuda.Event(enable_timing=True)
end_event = torch.cuda.Event(enable_timing=True)

# Input batch size of 32 for processing speed analysis
batch_size = 32
input_tensor = torch.randn(batch_size, 3, 224, 224).to(device)  # Move input to GPU

# Measure processing time
model.eval()
start_event.record()
with torch.no_grad():
    for _ in range(10):  # Run multiple iterations for reliable results
        output = model(input_tensor)
end_event.record()

torch.cuda.synchronize()  # Wait for all operations to finish
elapsed_time = start_event.elapsed_time(end_event) / 10  # Average time in milliseconds
print(f"Average processing time per batch on GPU: {elapsed_time:.2f} ms")
time_per_image = elapsed_time / batch_size
print(f"Average processing time per image on GPU: {time_per_image:.2f} ms")
# Out:
# Average processing time per batch on GPU: 47.48 ms
# Average processing time per image on GPU: 1.48 ms

# %%
import time
# Move model and input to CPU
model = model.to('cpu')
input_tensor = input_tensor.to('cpu')

# Timing using CPU
start_time = time.time()
with torch.no_grad():
    for _ in range(10):
        output = model(input_tensor)
end_time = time.time()

cpu_time_per_batch = (end_time - start_time) / 10
print(f"Average processing time per batch on CPU: {cpu_time_per_batch:.2f} seconds")
cpu_time_per_image = cpu_time_per_batch / batch_size
print(f"Average processing time per image on CPU: {cpu_time_per_image:.2f} ms")
# Out:
# Average processing time per batch on CPU: 3.66 seconds
# Average processing time per image on CPU: 0.11 ms

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to display examples
def display_examples(images, labels, preds, indices, class_names, title, num_examples=5):
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(indices[:num_examples]):
        plt.subplot(1, num_examples, i + 1)
        img = images[idx].transpose(1, 2, 0)  # Convert to HWC format
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])  # Unnormalize
        img = np.clip(img, 0, 1)
        plt.imshow(img)
        pred_label = class_names[preds[idx]]
        true_label = class_names[labels[idx]]
        color = "green" if pred_label == true_label else "red"
        plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# %%
# Ensure the model is on the correct device
model.to(device)

# Collect images, labels, and predictions from the test loader
images, labels, preds = [], [], []
model.eval()
with torch.no_grad():
    for inputs, targets in test_loader:
        inputs, targets = inputs.to(device), targets.to(device)  # Move inputs and targets to the correct device
        outputs = model(inputs)  # Perform inference
        _, predicted = outputs.max(1)  # Get the predicted class indices

        images.extend(inputs.cpu().numpy())  # Move inputs back to CPU for visualization
        labels.extend(targets.cpu().numpy())
        preds.extend(predicted.cpu().numpy())

# Convert lists to NumPy arrays for easier handling
images = np.array(images)
labels = np.array(labels)
preds = np.array(preds)

# Identify correctly and incorrectly classified examples
correct_indices = np.where(preds == labels)[0]
incorrect_indices = np.where(preds != labels)[0]

# %%
# Display 5 correct predictions
display_examples(
    images, labels, preds, correct_indices, 
    test_dataset.classes, "Correctly Identified Examples", num_examples=5
)

# %%
# Display 5 incorrect predictions
display_examples(images, labels, preds, incorrect_indices, test_dataset.classes, "Wrongly Identified Examples", num_examples=5)

# %%
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np

# Function to group indices by label
def group_indices_by_label(labels, indices):
    label_dict = defaultdict(list)
    for idx in indices:
        label_dict[labels[idx]].append(idx)
    return label_dict

# Function to select diverse examples
def select_diverse_examples(grouped_indices, num_examples=5):
    selected_indices = []
    for label, idx_list in grouped_indices.items():
        if len(selected_indices) < num_examples:
            selected_indices.extend(idx_list[:1])  # Take one example per label
    return selected_indices[:num_examples]

# Function to display examples
def display_diverse_examples(images, labels, preds, indices, class_names, title, num_examples=5):
    grouped_indices = group_indices_by_label(labels, indices)  # Group by true label
    selected_indices = select_diverse_examples(grouped_indices, num_examples=num_examples)  # Select diverse examples

    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(selected_indices):
        plt.subplot(1, num_examples, i + 1)
        img = images[idx].transpose(1, 2, 0)  # Convert to HWC format
        img = img * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])  # Unnormalize
        img = np.clip(img, 0, 1)
        plt.imshow(img)
        pred_label = class_names[preds[idx]]
        true_label = class_names[labels[idx]]
        color = "green" if pred_label == true_label else "red"
        plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# %%
# Display diverse correct predictions
display_diverse_examples(images, labels, preds, correct_indices, test_dataset.classes, "Correctly Identified Examples (Diverse)", num_examples=5)

# %%
# Display diverse incorrect predictions
display_diverse_examples(images, labels, preds, incorrect_indices, test_dataset.classes, "Wrongly Identified Examples (Diverse)", num_examples=5)
